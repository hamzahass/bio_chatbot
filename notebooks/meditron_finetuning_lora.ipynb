# %% [markdown]
# # Modeling with Meditron

# %% [markdown]
# code :

# %%
# !pip -q install datasets loralib sentencepiece trl mlflow bitsandbytes
# !pip -q install git+https://github.com/huggingface/transformers # need to install from github
# !pip -q install git+https://github.com/huggingface/peft.git
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done

# %%
HUGGING_FACE_TOKEN='ADD_YOUR_HUGGING_FACE_TOKEN'

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd gdrive/MyDrive/dl_chatbot
# Out:
# /content/gdrive/MyDrive/dl_chatbot

# %% [markdown]
# ## Data processing for finetuning

# %%
import torch
import torch.nn as nn
import pandas as pd
import bitsandbytes as bnb
import transformers
from transformers import AutoConfig, AutoTokenizer, AutoModelForCausalLM, GenerationConfig
from transformers import TrainingArguments
from trl import SFTTrainer

from peft import prepare_model_for_int8_training, LoraConfig, get_peft_model

from datasets import load_dataset, load_from_disk, Dataset, DatasetDict
# Out:
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_config.py:141: UserWarning: The `optimize_cuda_cache` arguement will be deprecated soon, please use `optimize_device_cache` instead.
#   warnings.warn(

# %%
tokenizer = AutoTokenizer.from_pretrained("epfl-llm/meditron-7b", token=HUGGING_FACE_TOKEN, add_eos_token=True)

tokenizer.add_special_tokens({'pad_token': '[PAD]'})
# Out:
# tokenizer_config.json:   0%|          | 0.00/4.08k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.85M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/344 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/736 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# 1

# %%
def generate_prompt(data_point):
    # taken from https://github.com/tloen/alpaca-lora
    return f""" Below is a medical question below, provide an answer to it.
    ### Question :
    {data_point["question"]}

    ### Answer :
    {data_point["answer"]}"""

# %%
# Load the dataset
data  = load_dataset("json", data_files="final_qa_dataset.json")

data = pd.DataFrame(data['train'])

# %%
# We reduce the size of our dataset because of limited ressources
DATA_LIMIT = 120000

# %%
data = data[:DATA_LIMIT]

# %%
data['text'] = data.apply(lambda x : generate_prompt(x), axis=1)

# %%
data.head()
# Out:
#                                             question  \
# 0       What is (are) keratoderma with woolly hair ?
# 1  How many people are affected by keratoderma wi...
# 2  What are the genetic changes related to kerato...
# 3        Is keratoderma with woolly hair inherited ?
# 4  What are the treatments for keratoderma with w...
#
#                                               answer  \
# 0  Keratoderma with woolly hair is a group of rel...
# 1  Keratoderma with woolly hair is rare; its prev...
# 2  Mutations in the JUP, DSP, DSC2, and KANK2 gen...
# 3  Most cases of keratoderma with woolly hair hav...
# 4  These resources address the diagnosis or manag...
#
#                                                 text
# 0   Below is a medical question below, provide an...
# 1   Below is a medical question below, provide an...
# 2   Below is a medical question below, provide an...
# 3   Below is a medical question below, provide an...
# 4   Below is a medical question below, provide an...

# %%
dataset = Dataset.from_pandas(data[['question', 'text']]).train_test_split(test_size=0.05, seed=42)

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['question', 'text'],
#         num_rows: 190
#     })
#     test: Dataset({
#         features: ['question', 'text'],
#         num_rows: 10
#     })
# })

# %%
# Tokenizing our data for the fine-tuning
CUTOFF_LEN = 4096

dataset = dataset.map(
    lambda data_point: tokenizer(
        data_point['text'],
        truncation=True,
        max_length=CUTOFF_LEN,
        padding="max_length",
    )
)
# Out:
# Map:   0%|          | 0/114000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/6000 [00:00<?, ? examples/s]

# %%
dataset.save_to_disk('tokenized_dataset_100k')

# %%
#%cd ../../../
# !zip -r /tokenized_dataset_100k.zip tokenized_dataset_100k

from google.colab import files
files.download("/tokenized_dataset_100k.zip")
# Out:
#   adding: tokenized_dataset_100k/ (stored 0%)
#   adding: tokenized_dataset_100k/test/ (stored 0%)
#   adding: tokenized_dataset_100k/test/dataset_info.json (deflated 67%)
#   adding: tokenized_dataset_100k/test/state.json (deflated 38%)
#   adding: tokenized_dataset_100k/test/data-00000-of-00001.arrow (deflated 98%)
#   adding: tokenized_dataset_100k/dataset_dict.json (stored 0%)
#   adding: tokenized_dataset_100k/train/ (stored 0%)
#   adding: tokenized_dataset_100k/train/data-00003-of-00005.arrow (deflated 98%)
#   adding: tokenized_dataset_100k/train/data-00004-of-00005.arrow (deflated 98%)
#   adding: tokenized_dataset_100k/train/data-00001-of-00005.arrow (deflated 98%)
#   adding: tokenized_dataset_100k/train/dataset_info.json (deflated 67%)
#   adding: tokenized_dataset_100k/train/state.json (deflated 65%)
#   adding: tokenized_dataset_100k/train/data-00002-of-00005.arrow (deflated 98%)
#   adding: tokenized_dataset_100k/train/data-00000-of-00005.arrow (deflated 98%)

# %% [markdown]
# ## Script like modeling

# %%
data  = load_from_disk("tokenized_dataset_100k")

print("Data loaded \n")
# Out:
# Data loaded

# %%
LORA_R = 4
LORA_ALPHA = 16
LORA_DROPOUT = 0.05

lora_config = LoraConfig(
    r=LORA_R,
    lora_alpha=LORA_ALPHA,
    target_modules=["q_proj", "v_proj"],
    lora_dropout=LORA_DROPOUT,
    bias="none",
    task_type="CAUSAL_LM",
)

base_dir = "lora-dolly"

per_device_train_batch_size = 4
gradient_accumulation_steps = 4
optim = 'adamw_hf'
learning_rate = 1e-5
max_grad_norm = 0.3
warmup_ratio = 0.03
lr_scheduler_type = "linear"
EPOCHS = 2

# %%
model = AutoModelForCausalLM.from_pretrained("epfl-llm/meditron-7b", token=HUGGING_FACE_TOKEN, load_in_8bit=True,
    device_map="auto")

model = get_peft_model(model, lora_config)

model.print_trainable_parameters()

print("Model loaded \n")
# Out:
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]
# trainable params: 2,097,152 || all params: 6,740,652,032 || trainable%: 0.031112005041117066
# Model loaded

# %%
# Training Arguments and Trainer Initialization
training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=3,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    warmup_steps=500,
    weight_decay=0.01,
    logging_dir='./logs',
    logging_steps=10,
    evaluation_strategy="steps",
    save_steps=10,
    load_best_model_at_end=True
)

trainer = SFTTrainer(
   model,
   train_dataset=dataset['train'],
   eval_dataset = dataset['test'],
   dataset_text_field="text",
   max_seq_length=512,
   args=training_args,
)

print("Trainer set \n")

#Upcast layer norms to float 32 for stability
for name, module in trainer.model.named_modules():
 if "norm" in name:
   module = module.to(torch.float32)
# Out:
# Trainer set

# %%
print("Training starting \n")

# Initiate the training process
trainer.train()
# Out:
# Training starting
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-0b91193346e2> in <cell line: 4>()
#       2
#       3 # Initiate the training process
# ----> 4 trainer.train()
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1538                 hf_hub_utils.enable_progress_bars()
#    1539         else:
# -> 1540             return inner_training_loop(
#    1541                 args=args,
#    1542                 resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1673                     model = self.accelerator.prepare(self.model)
#    1674                 else:
# -> 1675                     model, self.optimizer = self.accelerator.prepare(self.model, self.optimizer)
#    1676             else:
#    1677                 # to handle cases wherein we pass "DummyScheduler" such as when it is specified in DeepSpeed config.
#
# /usr/local/lib/python3.10/dist-packages/accelerate/accelerator.py in prepare(self, device_placement, *args)
#    1211             result = self._prepare_megatron_lm(*args)
#    1212         else:
# -> 1213             result = tuple(
#    1214                 self._prepare_one(obj, first_pass=True, device_placement=d) for obj, d in zip(args, device_placement)
#    1215             )
#
# /usr/local/lib/python3.10/dist-packages/accelerate/accelerator.py in <genexpr>(.0)
#    1212         else:
#    1213             result = tuple(
# -> 1214                 self._prepare_one(obj, first_pass=True, device_placement=d) for obj, d in zip(args, device_placement)
#    1215             )
#    1216             result = tuple(self._prepare_one(obj, device_placement=d) for obj, d in zip(result, device_placement))
#
# /usr/local/lib/python3.10/dist-packages/accelerate/accelerator.py in _prepare_one(self, obj, first_pass, device_placement)
#    1092                 return self.prepare_data_loader(obj, device_placement=device_placement)
#    1093             elif isinstance(obj, torch.nn.Module):
# -> 1094                 return self.prepare_model(obj, device_placement=device_placement)
#    1095             elif isinstance(obj, torch.optim.Optimizer):
#    1096                 optimizer = self.prepare_optimizer(obj, device_placement=device_placement)
#
# /usr/local/lib/python3.10/dist-packages/accelerate/accelerator.py in prepare_model(self, model, device_placement, evaluation_mode)
#    1319             current_device_index = current_device.index if isinstance(current_device, torch.device) else current_device
#    1320
# -> 1321             if torch.device(current_device_index) != self.device:
#    1322                 # if on the first device (GPU 0) we don't care
#    1323                 if (self.device.index is not None) or (current_device_index != 0):
#
# TypeError: device() received an invalid combination of arguments - got (NoneType), but expected one of:
#  * (torch.device device)
#       didn't match because some of the arguments have invalid types: (!NoneType!)
#  * (str type, int index)

# %%
print("Training finished")

model.save_pretrained("meditron-lora-dolly")
